# %% [markdown]
# ## Trabajo Fin de Máster <br/> Diseño de una arquitectura multimodal para descripción textual de pares imagen-audio
#
# ## Script 5. Entrenamiento del modelo CLIP con base de datos propia
#
# En este notebook, unimos las bases de datos de imagen y audio, creando un dataframe (posteriormente guardado en un csv) en el que emparejamos imágenes con audios, sin seguir ningún tipo de criterio.
#
# Dado que hay muchos menos audios que imágenes, lo que se hace es asignar el mismo audio a varias imágenes, cosa que hacemos recorriendo la lista de audios en ciclo.

# %% [markdown]
# ### Paso 1. Montamos el almacenamiento
#
# Damos permiso a Colab para acceder a mi unidad de Drive y nos situamos en la carpeta donde tenemos los scripts y la librería que hemos creado con las clases propias.

# %%
from google.colab import drive
drive.mount('/content/drive')

# %cd /content/drive/MyDrive/TFM/Proyecto/Scripts
# Out:
# Mounted at /content/drive
# /content/drive/MyDrive/TFM/Proyecto/Scripts

# %% [markdown]
# ### Paso 2. Lectura de las bases de datos
#
# Leemos los documentos csv en los que guardamos la información sobre las bases de datos de imagen y audio.

# %%
import pandas as pd

images = pd.read_csv('../Final_Database_mini/image/imagesDB.csv')
audios = pd.read_csv('../Final_Database_mini/audio/audioDB.csv')

# %%
images.head()
# Out:
#                                           image_path  \
# 0  ../Final_Database_mini/image/Jose Alberto Azor...
# 1  ../Final_Database_mini/image/Jose Alberto Azor...
# 2  ../Final_Database_mini/image/Jose Alberto Azor...
# 3  ../Final_Database_mini/image/Jose Alberto Azor...
# 4  ../Final_Database_mini/image/Jose Alberto Azor...
#
#                      classID
# 0  Jose Alberto Azorin Puche
# 1  Jose Alberto Azorin Puche
# 2  Jose Alberto Azorin Puche
# 3  Jose Alberto Azorin Puche
# 4  Jose Alberto Azorin Puche

# %%
audios.head()
# Out:
#                                           audio_path  \
# 0  ../Final_Database_mini/audio/Jose Alberto Azor...
# 1  ../Final_Database_mini/audio/Jose Alberto Azor...
# 2  ../Final_Database_mini/audio/Jose Alberto Azor...
# 3  ../Final_Database_mini/audio/Jose Alberto Azor...
# 4  ../Final_Database_mini/audio/Jose Alberto Azor...
#
#                      classID
# 0  Jose Alberto Azorin Puche
# 1  Jose Alberto Azorin Puche
# 2  Jose Alberto Azorin Puche
# 3  Jose Alberto Azorin Puche
# 4  Jose Alberto Azorin Puche

# %% [markdown]
# ### Paso 3. Fusión de los dataframes

# %%
final_db = images.copy()

# %%
from itertools import cycle

for clase in audios.classID.unique():
    selected_rows = final_db.classID==clase
    audios_ciclo = cycle(audios[audios.classID==clase].audio_path.unique())
    final_db.loc[selected_rows, 'audio_path'] = [next(audios_ciclo) for _ in range(selected_rows.sum())]

final_db
# Out:
#                                              image_path  \
# 0     ../Final_Database_mini/image/Jose Alberto Azor...
# 1     ../Final_Database_mini/image/Jose Alberto Azor...
# 2     ../Final_Database_mini/image/Jose Alberto Azor...
# 3     ../Final_Database_mini/image/Jose Alberto Azor...
# 4     ../Final_Database_mini/image/Jose Alberto Azor...
# ...                                                 ...
# 3075  ../Final_Database_mini/image/Juanjo Bautista I...
# 3076  ../Final_Database_mini/image/Juanjo Bautista I...
# 3077  ../Final_Database_mini/image/Juanjo Bautista I...
# 3078  ../Final_Database_mini/image/Juanjo Bautista I...
# 3079  ../Final_Database_mini/image/Juanjo Bautista I...
#
#                         classID  \
# 0     Jose Alberto Azorin Puche
# 1     Jose Alberto Azorin Puche
# 2     Jose Alberto Azorin Puche
# 3     Jose Alberto Azorin Puche
# 4     Jose Alberto Azorin Puche
# ...                         ...
# 3075     Juanjo Bautista Ibanez
# 3076     Juanjo Bautista Ibanez
# 3077     Juanjo Bautista Ibanez
# 3078     Juanjo Bautista Ibanez
# 3079     Juanjo Bautista Ibanez
#
#                                              audio_path
# 0     ../Final_Database_mini/audio/Jose Alberto Azor...
# 1     ../Final_Database_mini/audio/Jose Alberto Azor...
# 2     ../Final_Database_mini/audio/Jose Alberto Azor...
# 3     ../Final_Database_mini/audio/Jose Alberto Azor...
# 4     ../Final_Database_mini/audio/Jose Alberto Azor...
# ...                                                 ...
# 3075  ../Final_Database_mini/audio/Juanjo Bautista I...
# 3076  ../Final_Database_mini/audio/Juanjo Bautista I...
# 3077  ../Final_Database_mini/audio/Juanjo Bautista I...
# 3078  ../Final_Database_mini/audio/Juanjo Bautista I...
# 3079  ../Final_Database_mini/audio/Juanjo Bautista I...
#
# [3080 rows x 3 columns]

# %%
final_db.to_csv('../Final_Database_mini/final_db.csv', index=False)
